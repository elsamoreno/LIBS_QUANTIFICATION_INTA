# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Funciones auxiliares
def leer_archivo_txt(nombre_archivo, saltar_lineas=5, delimitador=';'):
    try:
        df = pd.read_csv(nombre_archivo, delimiter=delimitador, skiprows=saltar_lineas)
        df.columns = df.columns.str.strip()
        df['Wave'] = pd.to_numeric(df['Wave'], errors='coerce')
        df['Sample'] = pd.to_numeric(df['Sample'], errors='coerce')
        df.dropna(inplace=True)
        return df
    except Exception as e:
        print(f"Error al leer el archivo: {e}")
        return None
    
def graficar_datos(df, columna_x, columna_y):
    
    plt.figure(figsize=(8, 5))
    plt.plot(df[columna_x], df[columna_y], marker='', linestyle='-')
    plt.xlabel(columna_x)
    plt.ylabel(columna_y)
    plt.title(f"Gráfica de {columna_y} vs {columna_x}")
    plt.grid()
    plt.show()


def graficar_multiples_dfs(lista_dfs, nombres, título, columna_x, columna_y):
    
    plt.figure(figsize=(8, 5))
    for df, nombre in zip(lista_dfs, nombres):
        if df is not None and columna_x in df.columns and columna_y in df.columns:
            plt.plot(df[columna_x], df[columna_y], marker='', linestyle='-', markersize=3, linewidth=0.8, label=nombre)
        else:
            print(f"Error: No se pudo graficar {nombre}, columnas no encontradas")
    plt.xlabel(columna_x)
    plt.ylabel(columna_y)
    plt.title(título)
    plt.legend()
    plt.minorticks_on()  # Habilitar las marcas menores
    plt.grid(which='both', linestyle='-', linewidth=0.5, alpha=0.7)
    # Ajustar los márgenes de manera manual
    plt.subplots_adjust(left=0.1, right=0.9, bottom=0.1, top=0.9)
    plt.show()

# %%
#Leer archivos

UV1 = "20250321_First_test\Sulfato50_shot01_7324767SP.txt" 
UV2 = "20250321_First_test\Sulfato50_shot01_7324768SP.txt" 
VIS = "20250321_First_test\Sulfato50_shot01_7324769SP.txt" 
NIR = "20250321_First_test\Sulfato50_shot01_7324770SP.txt" 

datos_UV1 = leer_archivo_txt(UV1)
datos_UV2 = leer_archivo_txt(UV2)
datos_VIS = leer_archivo_txt(VIS)
datos_NIR = leer_archivo_txt(NIR)

# %%
#Declaración de los intervalos de solapamiento

wls_UV1 = datos_UV1['Wave']
wls_UV2 = datos_UV2['Wave']
wls_VIS = datos_VIS['Wave']
wls_NIR = datos_NIR['Wave']
i1 = (wls_UV2[1], wls_UV1[len(wls_UV1)-1])
i2 = (wls_VIS[1], wls_UV2[len(wls_UV2)-1])
i3 = (wls_NIR[1], wls_VIS[len(wls_VIS)-1])

# %%
#Aislamiento de los intervalos de solapamiento

datos_UV1_fil1 = datos_UV1[(datos_UV1['Wave'] >= i1[0]) & (datos_UV1['Wave'] <= i1[1])]
datos_UV2_fil1 = datos_UV2[(datos_UV2['Wave'] >= i1[0]) & (datos_UV2['Wave'] <= i1[1])]

datos_UV2_fil2 = datos_UV2[(datos_UV2['Wave'] >= i2[0]) & (datos_UV2['Wave'] <= i2[1])]
datos_VIS_fil2 = datos_VIS[(datos_VIS['Wave'] >= i2[0]) & (datos_VIS['Wave'] <= i2[1])]

datos_VIS_fil3 = datos_VIS[(datos_VIS['Wave'] >= i3[0]) & (datos_VIS['Wave'] <= i3[1])]
datos_NIR_fil3 = datos_NIR[(datos_NIR['Wave'] >= i3[0]) & (datos_NIR['Wave'] <= i3[1])]

# %%
#Extracción de las medianas

mediana_UV1_fil1 = datos_UV1_fil1['Sample'].median()
mediana_UV2_fil1 = datos_UV2_fil1['Sample'].median()

mediana_UV2_fil2 = datos_UV2_fil2['Sample'].median()
mediana_VIS_fil2 = datos_VIS_fil2['Sample'].median()

mediana_VIS_fil3 = datos_VIS_fil3['Sample'].median()
mediana_NIR_fil3 = datos_NIR_fil3['Sample'].median()

# %%
#Cálculo de los coeficientes

coef1 = mediana_UV1_fil1/mediana_UV2_fil1
coef2 = mediana_UV2_fil2/mediana_VIS_fil2
coef3 = mediana_VIS_fil3/mediana_NIR_fil3

coef3
# Out:
# np.float64(1.609017175572519)

# %%
#Corrección del offset

datos_UV1_corr = datos_UV1.copy()
datos_UV2_corr = datos_UV2.copy()
datos_VIS_corr = datos_VIS.copy()
datos_NIR_corr = datos_NIR.copy()

datos_UV1_corr['Sample'] = datos_UV1_corr['Sample']
datos_UV2_corr['Sample'] = datos_UV2_corr['Sample']*coef1
datos_VIS_corr['Sample'] = datos_VIS_corr['Sample']*coef2*coef1
datos_NIR_corr['Sample'] = datos_NIR_corr['Sample']*coef3*coef2*coef1



dfs_calibrados = [datos_UV1_corr, datos_UV2_corr, datos_VIS_corr, datos_NIR_corr]
nombres_calibrados = ["UV1 Calibrado", "UV2 Calibrado", "VIS Calibrado", "NIR Calibrado"]
graficar_multiples_dfs(dfs_calibrados, nombres_calibrados, "Shot 1", 'Wave', 'Sample')

# %%
# Representación de la posición 3

UV1_n1 = "20250321_First_test\Sulfato50_position3_Burst5-n1_7324767SP.txt"
UV2_n1 = "20250321_First_test\Sulfato50_position3_Burst5-n1_7324768SP.txt" 
VIS_n1 = "20250321_First_test\Sulfato50_position3_Burst5-n1_7324769SP.txt" 
NIR_n1 = "20250321_First_test\Sulfato50_position3_Burst5-n1_7324770SP.txt" 
UV1_n2 = "20250321_First_test\Sulfato50_position3_Burst5-n2_7324767SP.txt"
UV2_n2 = "20250321_First_test\Sulfato50_position3_Burst5-n2_7324768SP.txt" 
VIS_n2 = "20250321_First_test\Sulfato50_position3_Burst5-n2_7324769SP.txt" 
NIR_n2 = "20250321_First_test\Sulfato50_position3_Burst5-n2_7324770SP.txt"
UV1_n3 = "20250321_First_test\Sulfato50_position3_Burst5-n3_7324767SP.txt"
UV2_n3 = "20250321_First_test\Sulfato50_position3_Burst5-n3_7324768SP.txt" 
VIS_n3 = "20250321_First_test\Sulfato50_position3_Burst5-n3_7324769SP.txt" 
NIR_n3 = "20250321_First_test\Sulfato50_position3_Burst5-n3_7324770SP.txt"
UV1_n4 = "20250321_First_test\Sulfato50_position3_Burst5-n4_7324767SP.txt"
UV2_n4 = "20250321_First_test\Sulfato50_position3_Burst5-n4_7324768SP.txt" 
VIS_n4 = "20250321_First_test\Sulfato50_position3_Burst5-n4_7324769SP.txt" 
NIR_n4 = "20250321_First_test\Sulfato50_position3_Burst5-n4_7324770SP.txt"
UV1_n5 = "20250321_First_test\Sulfato50_position3_Burst5-n5_7324767SP.txt"
UV2_n5 = "20250321_First_test\Sulfato50_position3_Burst5-n5_7324768SP.txt" 
VIS_n5 = "20250321_First_test\Sulfato50_position3_Burst5-n5_7324769SP.txt" 
NIR_n5 = "20250321_First_test\Sulfato50_position3_Burst5-n5_7324770SP.txt"

datos_UV1_n1 = leer_archivo_txt(UV1_n1)
datos_UV2_n1 = leer_archivo_txt(UV2_n1)
datos_VIS_n1 = leer_archivo_txt(VIS_n1)
datos_NIR_n1 = leer_archivo_txt(NIR_n1)
datos_UV1_n2 = leer_archivo_txt(UV1_n2)
datos_UV2_n2 = leer_archivo_txt(UV2_n2)
datos_VIS_n2 = leer_archivo_txt(VIS_n2)
datos_NIR_n2 = leer_archivo_txt(NIR_n2)
datos_UV1_n3 = leer_archivo_txt(UV1_n3)
datos_UV2_n3 = leer_archivo_txt(UV2_n3)
datos_VIS_n3 = leer_archivo_txt(VIS_n3)
datos_NIR_n3 = leer_archivo_txt(NIR_n3)
datos_UV1_n4 = leer_archivo_txt(UV1_n4)
datos_UV2_n4 = leer_archivo_txt(UV2_n4)
datos_VIS_n4 = leer_archivo_txt(VIS_n4)
datos_NIR_n4 = leer_archivo_txt(NIR_n4)
datos_UV1_n5 = leer_archivo_txt(UV1_n5)
datos_UV2_n5 = leer_archivo_txt(UV2_n5)
datos_VIS_n5 = leer_archivo_txt(VIS_n5)
datos_NIR_n5 = leer_archivo_txt(NIR_n5)

dfs1 = [datos_UV1_n1, datos_UV2_n1, datos_VIS_n1, datos_NIR_n1]
nombres1 = ["UV1", "UV2", "VIS", "NIR "]
graficar_multiples_dfs(dfs1, nombres1, "Position 3 - n1", 'Wave', 'Sample')

dfs2 = [datos_UV1_n2, datos_UV2_n2, datos_VIS_n2, datos_NIR_n2]
nombres2 = ["UV1", "UV2", "VIS", "NIR "]
graficar_multiples_dfs(dfs2, nombres2, "Position 3 - n2", 'Wave', 'Sample')

dfs3 = [datos_UV1_n3, datos_UV2_n3, datos_VIS_n3, datos_NIR_n3]
nombres3 = ["UV1", "UV2", "VIS", "NIR "]
graficar_multiples_dfs(dfs3, nombres3, "Position 3 - n3", 'Wave', 'Sample')

dfs4 = [datos_UV1_n4, datos_UV2_n4, datos_VIS_n4, datos_NIR_n4]
nombres4 = ["UV1", "UV2", "VIS", "NIR "]
graficar_multiples_dfs(dfs4, nombres4, "Position 3 - n4", 'Wave', 'Sample')

dfs5 = [datos_UV1_n5, datos_UV2_n5, datos_VIS_n5, datos_NIR_n5]
nombres5 = ["UV1", "UV2", "VIS", "NIR "]
graficar_multiples_dfs(dfs5, nombres5, "Position 3 - n5", 'Wave', 'Sample')

# %%
dfs_UV1 = [datos_UV1_n1, datos_UV1_n2, datos_UV1_n3, datos_UV1_n4, datos_UV1_n5]
nombres_UV1 = ["UV1-n1", "UV1-n2", "UV1-n3", "UV1-n4", "UV1-n5"]
graficar_multiples_dfs(dfs_UV1, nombres_UV1, "Position 3 - UV1", 'Wave', 'Sample')

dfs_UV2 = [datos_UV2_n1, datos_UV2_n2, datos_UV2_n3, datos_UV2_n4, datos_UV2_n5]
nombres_UV2 = ["UV2-n1", "UV2-n2", "UV2-n3", "UV2-n4", "UV2-n5"]
graficar_multiples_dfs(dfs_UV2, nombres_UV2, "Position 3 - UV2", 'Wave', 'Sample')

dfs_VIS = [datos_VIS_n1, datos_VIS_n2, datos_VIS_n3, datos_VIS_n4, datos_VIS_n5]
nombres_VIS = ["VIS-n1", "VIS-n2", "VIS-n3", "VIS-n4", "VIS-n5"]
graficar_multiples_dfs(dfs_VIS, nombres_VIS, "Position 3 - VIS", 'Wave', 'Sample')

dfs_NIR = [datos_NIR_n1, datos_NIR_n2, datos_NIR_n3, datos_NIR_n4, datos_NIR_n5]
nombres_NIR = ["NIR-n1", "NIR-n2", "NIR-n3", "NIR-n4", "NIR-n5"]
graficar_multiples_dfs(dfs_NIR, nombres_NIR, "Position 3 - NIR", 'Wave', 'Sample')
