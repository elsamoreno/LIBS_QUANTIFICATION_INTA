# %%
# Comparing Spectra

from spectra_analysis_fun import five_shot_representation
from tools_funs import leer_archivo_txt
from NIST_spectra import LIBS_over_NIST
from NIST_spectra import average_spectra
from tools_funs import graficar_multiples_dfs_32
from offset_fun import get_corrected_spectra
import pandas as pd

UV1_n2_prev = "../Spectra/20250321_First_test\Sulfato50_Burst5-n2_7324767SP.txt"
UV2_n2_prev = "../Spectra/20250321_First_test\Sulfato50_Burst5-n2_7324768SP.txt" 
VIS_n2_prev = "../Spectra/20250321_First_test\Sulfato50_Burst5-n2_7324769SP.txt" 
NIR_n2_prev = "../Spectra/20250321_First_test\Sulfato50_Burst5-n2_7324770SP.txt"
UV1_n1_prev = "../Spectra/20250321_First_test\Sulfato50_Position2_Burst5-n1_7324767SP.txt"
UV2_n1_prev = "../Spectra/20250321_First_test\Sulfato50_Position2_Burst5-n1_7324768SP.txt" 
VIS_n1_prev = "../Spectra/20250321_First_test\Sulfato50_Position2_Burst5-n1_7324769SP.txt" 
NIR_n1_prev = "../Spectra/20250321_First_test\Sulfato50_Position2_Burst5-n1_7324770SP.txt"
UV1_n3_prev = "../Spectra/20250321_First_test\Sulfato50_Position3_Burst5-n1_7324767SP.txt"
UV2_n3_prev = "../Spectra/20250321_First_test\Sulfato50_Position3_Burst5-n1_7324768SP.txt" 
VIS_n3_prev = "../Spectra/20250321_First_test\Sulfato50_Position3_Burst5-n1_7324769SP.txt" 
NIR_n3_prev = "../Spectra/20250321_First_test\Sulfato50_Position3_Burst5-n1_7324770SP.txt"
UV1_n2 = "../Spectra/20250328_OHO-SN3_LIBS-Quantif_samples/1.Pellets_T2/Position2\Pellet_Position2_Burst5-n2_7324767SP.txt"
UV2_n2 = "../Spectra/20250328_OHO-SN3_LIBS-Quantif_samples/1.Pellets_T2/Position2\Pellet_Position2_Burst5-n2_7324768SP.txt" 
VIS_n2 = "../Spectra/20250328_OHO-SN3_LIBS-Quantif_samples/1.Pellets_T2/Position2\Pellet_Position2_Burst5-n2_7324769SP.txt" 
NIR_n2 = "../Spectra/20250328_OHO-SN3_LIBS-Quantif_samples/1.Pellets_T2/Position2\Pellet_Position2_Burst5-n2_7324770SP.txt"
UV1_n4 = "../Spectra/20250328_OHO-SN3_LIBS-Quantif_samples/1.Pellets_T2/Position1\Pellet_Position1_Burst5-n4_7324767SP.txt"
UV2_n4 = "../Spectra/20250328_OHO-SN3_LIBS-Quantif_samples/1.Pellets_T2/Position1\Pellet_Position1_Burst5-n4_7324768SP.txt" 
VIS_n4 = "../Spectra/20250328_OHO-SN3_LIBS-Quantif_samples/1.Pellets_T2/Position1\Pellet_Position1_Burst5-n4_7324769SP.txt" 
NIR_n4 = "../Spectra/20250328_OHO-SN3_LIBS-Quantif_samples/1.Pellets_T2/Position1\Pellet_Position1_Burst5-n4_7324770SP.txt"
UV1_n5 = "../Spectra/20250328_OHO-SN3_LIBS-Quantif_samples/1.Pellets_T2/Position3\Pellet_Position3_Burst5-n5_7324767SP.txt"
UV2_n5 = "../Spectra/20250328_OHO-SN3_LIBS-Quantif_samples/1.Pellets_T2/Position3\Pellet_Position3_Burst5-n5_7324768SP.txt" 
VIS_n5 = "../Spectra/20250328_OHO-SN3_LIBS-Quantif_samples/1.Pellets_T2/Position3\Pellet_Position3_Burst5-n5_7324769SP.txt" 
NIR_n5 = "../Spectra/20250328_OHO-SN3_LIBS-Quantif_samples/1.Pellets_T2/Position3\Pellet_Position3_Burst5-n5_7324770SP.txt"

datos_UV1_n2_prev = leer_archivo_txt(UV1_n2_prev)
datos_UV2_n2_prev = leer_archivo_txt(UV2_n2_prev)
datos_VIS_n2_prev = leer_archivo_txt(VIS_n2_prev)
datos_NIR_n2_prev = leer_archivo_txt(NIR_n2_prev)
datos_UV1_n1_prev = leer_archivo_txt(UV1_n1_prev)
datos_UV2_n1_prev = leer_archivo_txt(UV2_n1_prev)
datos_VIS_n1_prev = leer_archivo_txt(VIS_n1_prev)
datos_NIR_n1_prev = leer_archivo_txt(NIR_n1_prev)
datos_UV1_n3_prev = leer_archivo_txt(UV1_n3_prev)
datos_UV2_n3_prev = leer_archivo_txt(UV2_n3_prev)
datos_VIS_n3_prev = leer_archivo_txt(VIS_n3_prev)
datos_NIR_n3_prev = leer_archivo_txt(NIR_n3_prev)
datos_UV1_n2 = leer_archivo_txt(UV1_n2)
datos_UV2_n2 = leer_archivo_txt(UV2_n2)
datos_VIS_n2 = leer_archivo_txt(VIS_n2)
datos_NIR_n2 = leer_archivo_txt(NIR_n2)
datos_UV1_n4 = leer_archivo_txt(UV1_n4)
datos_UV2_n4 = leer_archivo_txt(UV2_n4)
datos_VIS_n4 = leer_archivo_txt(VIS_n4)
datos_NIR_n4 = leer_archivo_txt(NIR_n4)
datos_UV1_n5 = leer_archivo_txt(UV1_n5)
datos_UV2_n5 = leer_archivo_txt(UV2_n5)
datos_VIS_n5 = leer_archivo_txt(VIS_n5)
datos_NIR_n5 = leer_archivo_txt(NIR_n5)

# %%
datos_UV1_n2, datos_UV2_n2, datos_VIS_n2, datos_NIR_n2 = get_corrected_spectra(datos_UV1_n2, datos_UV2_n2, datos_VIS_n2, datos_NIR_n2)
datos_UV1_n2, datos_UV2_n2, datos_VIS_n2, datos_NIR_n2 = get_corrected_spectra(datos_UV1_n2, datos_UV2_n2, datos_VIS_n2, datos_NIR_n2)
datos_UV1_n5, datos_UV2_n5, datos_VIS_n5, datos_NIR_n5 = get_corrected_spectra(datos_UV1_n5, datos_UV2_n5, datos_VIS_n5, datos_NIR_n5)
datos_UV1_n2_prev, datos_UV2_n2_prev, datos_VIS_n2_prev, datos_NIR_n2_prev = get_corrected_spectra(datos_UV1_n2_prev, datos_UV2_n2_prev, datos_VIS_n2_prev, datos_NIR_n2_prev)
datos_UV1_n1_prev, datos_UV2_n1_prev, datos_VIS_n1_prev, datos_NIR_n1_prev = get_corrected_spectra(datos_UV1_n1_prev, datos_UV2_n1_prev, datos_VIS_n1_prev, datos_NIR_n1_prev)
datos_UV1_n3_prev, datos_UV2_n3_prev, datos_VIS_n3_prev, datos_NIR_n3_prev = get_corrected_spectra(datos_UV1_n3_prev, datos_UV2_n3_prev, datos_VIS_n3_prev, datos_NIR_n3_prev)
# Para la P1 tomar el n4
P1_n4 = pd.concat([datos_UV1_n2, datos_UV2_n2, datos_VIS_n2, datos_NIR_n2])
# Para la P2 tomar el n2
P2_n2 = pd.concat([datos_UV1_n2, datos_UV2_n2, datos_VIS_n2, datos_NIR_n2])
# Para la P3 tomar el n5
P3_n5 = pd.concat([datos_UV1_n5, datos_UV2_n5, datos_VIS_n5, datos_NIR_n5])
# Para la P1 de los datos previos tomar el n2
P1_n2_prev = pd.concat([datos_UV1_n2_prev, datos_UV2_n2_prev, datos_VIS_n2_prev, datos_NIR_n2_prev])
# Para la P2 de los datos previos tomar el n1
P2_n1_prev = pd.concat([datos_UV1_n1_prev, datos_UV2_n1_prev, datos_VIS_n1_prev, datos_NIR_n1_prev])
# Para la P3 de los datos previos tomar el n3
P3_n3_prev = pd.concat([datos_UV1_n3_prev, datos_UV2_n3_prev, datos_VIS_n3_prev, datos_NIR_n3_prev])

dfs = [P1_n4, P2_n2, P3_n5, P1_n2_prev,P2_n1_prev, P3_n3_prev]
nombres = ["P1_n4", "P2_n2", "P3_n5", "P1_n2_prev","P2_n1_prev", "P3_n3_prev"]
graficar_multiples_dfs_32(dfs, nombres, 'Comparación trans ennegrecimiento', 'Wave', 'Sample')
