datos_NIR_n2_P1 = leer_archivo_txt(NIR_n2_P1)
datos_UV1_n3_P1 = leer_archivo_txt(UV1_n3_P1)
datos_UV2_n3_P1 = leer_archivo_txt(UV2_n3_P1)
datos_VIS_n3_P1 = leer_archivo_txt(VIS_n3_P1)
datos_NIR_n3_P1 = leer_archivo_txt(NIR_n3_P1)
datos_UV1_n4_P1 = leer_archivo_txt(UV1_n4_P1)
datos_UV2_n4_P1 = leer_archivo_txt(UV2_n4_P1)
datos_VIS_n4_P1 = leer_archivo_txt(VIS_n4_P1)
datos_NIR_n4_P1 = leer_archivo_txt(NIR_n4_P1)
datos_UV1_n5_P1 = leer_archivo_txt(UV1_n5_P1)
datos_UV2_n5_P1 = leer_archivo_txt(UV2_n5_P1)
datos_VIS_n5_P1 = leer_archivo_txt(VIS_n5_P1)
datos_NIR_n5_P1 = leer_archivo_txt(NIR_n5_P1)

# Position2
datos_UV1_n1_P2 = leer_archivo_txt(UV1_n1_P2)
datos_UV2_n1_P2 = leer_archivo_txt(UV2_n1_P2)
datos_VIS_n1_P2 = leer_archivo_txt(VIS_n1_P2)
datos_NIR_n1_P2 = leer_archivo_txt(NIR_n1_P2)
datos_UV1_n2_P2 = leer_archivo_txt(UV1_n2_P2)
datos_UV2_n2_P2 = leer_archivo_txt(UV2_n2_P2)
datos_VIS_n2_P2 = leer_archivo_txt(VIS_n2_P2)
datos_NIR_n2_P2 = leer_archivo_txt(NIR_n2_P2)
datos_UV1_n3_P2 = leer_archivo_txt(UV1_n3_P2)
datos_UV2_n3_P2 = leer_archivo_txt(UV2_n3_P2)
datos_VIS_n3_P2 = leer_archivo_txt(VIS_n3_P2)
datos_NIR_n3_P2 = leer_archivo_txt(NIR_n3_P2)
datos_UV1_n4_P2 = leer_archivo_txt(UV1_n4_P2)
datos_UV2_n4_P2 = leer_archivo_txt(UV2_n4_P2)
datos_VIS_n4_P2 = leer_archivo_txt(VIS_n4_P2)
datos_NIR_n4_P2 = leer_archivo_txt(NIR_n4_P2)
datos_UV1_n5_P2 = leer_archivo_txt(UV1_n5_P2)
datos_UV2_n5_P2 = leer_archivo_txt(UV2_n5_P2)
datos_VIS_n5_P2 = leer_archivo_txt(VIS_n5_P2)
datos_NIR_n5_P2 = leer_archivo_txt(NIR_n5_P2)

# Position3
datos_UV1_n1_P3 = leer_archivo_txt(UV1_n1_P3)
datos_UV2_n1_P3 = leer_archivo_txt(UV2_n1_P3)
datos_VIS_n1_P3 = leer_archivo_txt(VIS_n1_P3)
datos_NIR_n1_P3 = leer_archivo_txt(NIR_n1_P3)
datos_UV1_n2_P3 = leer_archivo_txt(UV1_n2_P3)
datos_UV2_n2_P3 = leer_archivo_txt(UV2_n2_P3)
datos_VIS_n2_P3 = leer_archivo_txt(VIS_n2_P3)
datos_NIR_n2_P3 = leer_archivo_txt(NIR_n2_P3)
datos_UV1_n3_P3 = leer_archivo_txt(UV1_n3_P3)
datos_UV2_n3_P3 = leer_archivo_txt(UV2_n3_P3)
datos_VIS_n3_P3 = leer_archivo_txt(VIS_n3_P3)
datos_NIR_n3_P3 = leer_archivo_txt(NIR_n3_P3)
datos_UV1_n4_P3 = leer_archivo_txt(UV1_n4_P3)
datos_UV2_n4_P3 = leer_archivo_txt(UV2_n4_P3)
datos_VIS_n4_P3 = leer_archivo_txt(VIS_n4_P3)
datos_NIR_n4_P3 = leer_archivo_txt(NIR_n4_P3)
datos_UV1_n5_P3 = leer_archivo_txt(UV1_n5_P3)
datos_UV2_n5_P3 = leer_archivo_txt(UV2_n5_P3)
datos_VIS_n5_P3 = leer_archivo_txt(VIS_n5_P3)
datos_NIR_n5_P3 = leer_archivo_txt(NIR_n5_P3)

# %%
datos_UV1_5shot_P1 = [datos_UV1_n1_P1, datos_UV1_n2_P1, datos_UV1_n3_P1, datos_UV1_n4_P1, datos_UV1_n5_P1]
datos_UV2_5shot_P1 = [datos_UV2_n1_P1, datos_UV2_n2_P1, datos_UV2_n3_P1, datos_UV2_n4_P1, datos_UV2_n5_P1]
datos_VIS_5shot_P1 = [datos_VIS_n1_P1, datos_VIS_n2_P1, datos_VIS_n3_P1, datos_VIS_n4_P1, datos_VIS_n5_P1]
datos_NIR_5shot_P1 = [datos_NIR_n1_P1, datos_NIR_n2_P1, datos_NIR_n3_P1, datos_NIR_n4_P1, datos_NIR_n5_P1]

datos_UV1_5shot_P2 = [datos_UV1_n1_P2, datos_UV1_n2_P2, datos_UV1_n3_P2, datos_UV1_n4_P2, datos_UV1_n5_P2]
datos_UV2_5shot_P2 = [datos_UV2_n1_P2, datos_UV2_n2_P2, datos_UV2_n3_P2, datos_UV2_n4_P2, datos_UV2_n5_P2]
datos_VIS_5shot_P2 = [datos_VIS_n1_P2, datos_VIS_n2_P2, datos_VIS_n3_P2, datos_VIS_n4_P2, datos_VIS_n5_P2]
datos_NIR_5shot_P2 = [datos_NIR_n1_P2, datos_NIR_n2_P2, datos_NIR_n3_P2, datos_NIR_n4_P2, datos_NIR_n5_P2]

datos_UV1_5shot_P3 = [datos_UV1_n1_P3, datos_UV1_n2_P3, datos_UV1_n3_P3, datos_UV1_n4_P3, datos_UV1_n5_P3]
datos_UV2_5shot_P3 = [datos_UV2_n1_P3, datos_UV2_n2_P3, datos_UV2_n3_P3, datos_UV2_n4_P3, datos_UV2_n5_P3]
datos_VIS_5shot_P3 = [datos_VIS_n1_P3, datos_VIS_n2_P3, datos_VIS_n3_P3, datos_VIS_n4_P3, datos_VIS_n5_P3]
datos_NIR_5shot_P3 = [datos_NIR_n1_P3, datos_NIR_n2_P3, datos_NIR_n3_P3, datos_NIR_n4_P3, datos_NIR_n5_P3]

# %%
five_shot_representation(datos_UV1_5shot_P1, datos_UV2_5shot_P1, datos_VIS_5shot_P1, datos_NIR_5shot_P1)

# %%
from scipy.signal import find_peaks
counts_VIS = datos_VIS_n5_P1['Sample']
wls_VIS = datos_VIS_n5_P1['Wave']
picos_VIS, propiedades_VIS = find_peaks(counts_VIS, prominence=1000,
                                                    height=25000,
                                                    distance=1)
longitudes_pico_VIS = wls_VIS[picos_VIS]
counts_pico_VIS = propiedades_VIS['peak_heights']
#print(longitudes_pico_VIS)
#print(counts_pico_VIS)

counts_NIR = datos_NIR_n5_P1['Sample']
wls_NIR = datos_NIR_n5_P1['Wave']
picos_NIR, propiedades_NIR = find_peaks(counts_NIR, prominence=1000,
                                                    height=5000,
                                                    distance=1)
longitudes_pico_NIR = wls_NIR[picos_NIR]
counts_pico_NIR = propiedades_NIR['peak_heights']
#print(longitudes_pico_NIR)
#print(counts_pico_NIR)


counts_UV2 = datos_UV2_n5_P1['Sample']
wls_UV2 = datos_UV2_n5_P1['Wave']
picos_UV2, propiedades_UV2 = find_peaks(counts_UV2, prominence=100,
                                                    height=2300,
                                                    distance=1)
longitudes_pico_UV2 = wls_UV2[picos_UV2]
counts_pico_UV2 = propiedades_UV2['peak_heights']
print(longitudes_pico_UV2)
print(counts_pico_UV2)

LIBS_over_NIST(datos_UV1_n1_P1, datos_UV2_n1_P1, datos_VIS_n1_P1, datos_NIR_n1_P1,"Na", 100)
# Out:
# 1699    448.12
# Name: Wave, dtype: float64
# [2414.175]

# %%
avg_UV1_P1 = average_spectra(datos_UV1_5shot_P1)
avg_UV1_P2 = average_spectra(datos_UV1_5shot_P2)
avg_UV1_P3 = average_spectra(datos_UV1_5shot_P3)
avg_UV2_P1 = average_spectra(datos_UV2_5shot_P1)
avg_UV2_P2 = average_spectra(datos_UV2_5shot_P2)
avg_UV2_P3 = average_spectra(datos_UV2_5shot_P3)
avg_VIS_P1 = average_spectra(datos_VIS_5shot_P1)
avg_VIS_P2 = average_spectra(datos_VIS_5shot_P2)
avg_VIS_P3 = average_spectra(datos_VIS_5shot_P3)
avg_NIR_P1 = average_spectra(datos_NIR_5shot_P1)
avg_NIR_P2 = average_spectra(datos_NIR_5shot_P2)
avg_NIR_P3 = average_spectra(datos_NIR_5shot_P3)
avg_UV1_corr_P1, avg_UV2_corr_P1, avg_VIS_corr_P1, avg_NIR_corr_P1 = get_corrected_spectra(avg_UV1_P1,avg_UV2_P1,avg_VIS_P1,avg_NIR_P1)
avg_UV1_corr_P2, avg_UV2_corr_P2, avg_VIS_corr_P2, avg_NIR_corr_P2 = get_corrected_spectra(avg_UV1_P2,avg_UV2_P2,avg_VIS_P2,avg_NIR_P2)
avg_UV1_corr_P3, avg_UV2_corr_P3, avg_VIS_corr_P3, avg_NIR_corr_P3 = get_corrected_spectra(avg_UV1_P3,avg_UV2_P3,avg_VIS_P3,avg_NIR_P3)

values_UV1_P1 = avg_UV1_corr_P1['Sample'].values
values_UV1_P1 = values_UV1_P1[16:-16]
values_UV1_sr_P1 = denoise_spectrum_uwt(values_UV1_P1,threshold_sigma=5)
avg_UV1_corr_P1 = avg_UV1_corr_P1.iloc[16:-16].copy()  
avg_UV1_corr_P1['Sample'] = values_UV1_sr_P1

values_UV1_P2 = avg_UV1_corr_P2['Sample'].values
values_UV1_P2 = values_UV1_P2[16:-16]
values_UV1_sr_P2 = denoise_spectrum_uwt(values_UV1_P2,threshold_sigma=5)
avg_UV1_corr_P2 = avg_UV1_corr_P2.iloc[16:-16].copy()  
avg_UV1_corr_P2['Sample'] = values_UV1_sr_P2

values_UV1_P3 = avg_UV1_corr_P3['Sample'].values
values_UV1_P3 = values_UV1_P3[16:-16]
values_UV1_sr_P3 = denoise_spectrum_uwt(values_UV1_P3,threshold_sigma=5)
avg_UV1_corr_P3 = avg_UV1_corr_P3.iloc[16:-16].copy()  
avg_UV1_corr_P3['Sample'] = values_UV1_sr_P3

values_UV2_P1 = avg_UV2_corr_P1['Sample'].values
values_UV2_P1 = values_UV2_P1[16:-16]
values_UV2_sr_P1 = denoise_spectrum_uwt(values_UV2_P1, threshold_sigma=5, level=5)
avg_UV2_corr_P1 = avg_UV2_corr_P1.iloc[16:-16].copy()  
avg_UV2_corr_P1['Sample'] = values_UV2_sr_P1

values_UV2_P2 = avg_UV2_corr_P2['Sample'].values
values_UV2_P2 = values_UV2_P2[16:-16]
values_UV2_sr_P2 = denoise_spectrum_uwt(values_UV2_P2, threshold_sigma=5, level=5)
avg_UV2_corr_P2 = avg_UV2_corr_P2.iloc[16:-16].copy()  
avg_UV2_corr_P2['Sample'] = values_UV2_sr_P2

values_UV2_P3 = avg_UV2_corr_P3['Sample'].values
values_UV2_P3 = values_UV2_P3[16:-16]
values_UV2_sr_P3 = denoise_spectrum_uwt(values_UV2_P3, threshold_sigma=5, level=5)
avg_UV2_corr_P3 = avg_UV2_corr_P3.iloc[16:-16].copy()  
avg_UV2_corr_P3['Sample'] = values_UV2_sr_P3

values_VIS_P1 = avg_VIS_corr_P1['Sample'].values
values_VIS_P1 = values_VIS_P1[16:-16]
values_VIS_sr_P1 = denoise_spectrum_uwt(values_VIS_P1, level=4)
avg_VIS_corr_P1 = avg_VIS_corr_P1.iloc[16:-16].copy()  
avg_VIS_corr_P1['Sample'] = values_VIS_sr_P1

values_VIS_P2 = avg_VIS_corr_P2['Sample'].values
values_VIS_P2 = values_VIS_P2[16:-16]
values_VIS_sr_P2 = denoise_spectrum_uwt(values_VIS_P2, level=4)
avg_VIS_corr_P2 = avg_VIS_corr_P2.iloc[16:-16].copy()  
avg_VIS_corr_P2['Sample'] = values_VIS_sr_P2

values_VIS_P3 = avg_VIS_corr_P3['Sample'].values
values_VIS_P3 = values_VIS_P3[16:-16]
values_VIS_sr_P3 = denoise_spectrum_uwt(values_VIS_P3, level=4)
avg_VIS_corr_P3 = avg_VIS_corr_P3.iloc[16:-16].copy()  
avg_VIS_corr_P3['Sample'] = values_VIS_sr_P3


values_NIR_P1 = avg_NIR_corr_P1['Sample'].values
values_NIR_P1 = values_NIR_P1[16:-16]
values_NIR_sr_P1 = denoise_spectrum_uwt(values_NIR_P1, level=4)
avg_NIR_corr_P1 = avg_NIR_corr_P1.iloc[16:-16].copy()  
avg_NIR_corr_P1['Sample'] = values_NIR_sr_P1

values_NIR_P2 = avg_NIR_corr_P2['Sample'].values
values_NIR_P2 = values_NIR_P2[16:-16]
values_NIR_sr_P2 = denoise_spectrum_uwt(values_NIR_P2, level=4)
avg_NIR_corr_P2 = avg_NIR_corr_P2.iloc[16:-16].copy()  
avg_NIR_corr_P2['Sample'] = values_NIR_sr_P2

values_NIR_P3 = avg_NIR_corr_P3['Sample'].values
values_NIR_P3 = values_NIR_P3[16:-16]
values_NIR_sr_P3 = denoise_spectrum_uwt(values_NIR_P3, level=4)
avg_NIR_corr_P3 = avg_NIR_corr_P3.iloc[16:-16].copy()  
avg_NIR_corr_P3['Sample'] = values_NIR_sr_P3

P1 = pd.concat([avg_UV1_corr_P1, avg_UV2_corr_P1, avg_VIS_corr_P1, avg_NIR_corr_P1], ignore_index=True)
P2 = pd.concat([avg_UV1_corr_P2, avg_UV2_corr_P2, avg_VIS_corr_P2, avg_NIR_corr_P2], ignore_index=True)
P3 = pd.concat([avg_UV1_corr_P3, avg_UV2_corr_P3, avg_VIS_corr_P3, avg_NIR_corr_P3], ignore_index=True)

dfs = [P1, P2, P3]
names = ["Position 1", "Position 2", "Position 3"]
graficar_multiples_dfs_32(dfs, names, "Espectro promediado", 'Wave', 'Sample')
#LIBS_over_NIST(avg_UV1_corr, avg_UV2_corr, avg_VIS_corr, avg_NIR_corr,"Mg", 3)
