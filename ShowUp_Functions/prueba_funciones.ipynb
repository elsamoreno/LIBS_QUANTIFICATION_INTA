# %%
from spectra_analysis_fun import five_shot_representation
from tools_funs import leer_archivo_txt

# %%
UV1_n1 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n1_7324767SP.txt"
UV2_n1 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n1_7324768SP.txt" 
VIS_n1 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n1_7324769SP.txt" 
NIR_n1 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n1_7324770SP.txt" 
UV1_n2 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n2_7324767SP.txt"
UV2_n2 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n2_7324768SP.txt" 
VIS_n2 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n2_7324769SP.txt" 
NIR_n2 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n2_7324770SP.txt"
UV1_n3 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n3_7324767SP.txt"
UV2_n3 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n3_7324768SP.txt" 
VIS_n3 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n3_7324769SP.txt" 
NIR_n3 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n3_7324770SP.txt"
UV1_n4 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n4_7324767SP.txt"
UV2_n4 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n4_7324768SP.txt" 
VIS_n4 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n4_7324769SP.txt" 
NIR_n4 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n4_7324770SP.txt"
UV1_n5 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n5_7324767SP.txt"
UV2_n5 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n5_7324768SP.txt" 
VIS_n5 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n5_7324769SP.txt" 
NIR_n5 = "../Spectra/20250321_First_test\Sulfato50_Burst5-n5_7324770SP.txt"

datos_UV1_n1 = leer_archivo_txt(UV1_n1)
datos_UV2_n1 = leer_archivo_txt(UV2_n1)
datos_VIS_n1 = leer_archivo_txt(VIS_n1)
datos_NIR_n1 = leer_archivo_txt(NIR_n1)
datos_UV1_n2 = leer_archivo_txt(UV1_n2)
datos_UV2_n2 = leer_archivo_txt(UV2_n2)
datos_VIS_n2 = leer_archivo_txt(VIS_n2)
datos_NIR_n2 = leer_archivo_txt(NIR_n2)
datos_UV1_n3 = leer_archivo_txt(UV1_n3)
datos_UV2_n3 = leer_archivo_txt(UV2_n3)
datos_VIS_n3 = leer_archivo_txt(VIS_n3)
datos_NIR_n3 = leer_archivo_txt(NIR_n3)
datos_UV1_n4 = leer_archivo_txt(UV1_n4)
datos_UV2_n4 = leer_archivo_txt(UV2_n4)
datos_VIS_n4 = leer_archivo_txt(VIS_n4)
datos_NIR_n4 = leer_archivo_txt(NIR_n4)
datos_UV1_n5 = leer_archivo_txt(UV1_n5)
datos_UV2_n5 = leer_archivo_txt(UV2_n5)
datos_VIS_n5 = leer_archivo_txt(VIS_n5)
datos_NIR_n5 = leer_archivo_txt(NIR_n5)

# %%
datos_UV1_5shot = [datos_UV1_n1, datos_UV1_n2, datos_UV1_n3, datos_UV1_n4, datos_UV1_n5]
datos_UV2_5shot = [datos_UV2_n1, datos_UV2_n2, datos_UV2_n3, datos_UV2_n4, datos_UV2_n5]
datos_VIS_5shot = [datos_VIS_n1, datos_VIS_n2, datos_VIS_n3, datos_VIS_n4, datos_VIS_n5]
datos_NIR_5shot = [datos_NIR_n1, datos_NIR_n2, datos_NIR_n3, datos_NIR_n4, datos_NIR_n5]

# %%
five_shot_representation(datos_UV1_5shot, datos_UV2_5shot, datos_VIS_5shot, datos_NIR_5shot)
