# %% [markdown]
# # Comprobación de la robustez frente a tiempo de integración

# %% [markdown]
# ## Cargamos los datos

# %% [markdown]
# ### Importamos Paquetes y funciones

# %%
import sys
sys.path.append('C:/Nacho/Universidad/Prácticas Raman/LIBS_QUANTIFICATION_INTA')
from LIBS_quantification_toolbox import *

# %% [markdown]
# ### Datos Completos

# %%
carpeta = 'M14_test'
wavelength,espectro_500 ,nombres = cargar_espectros_5shotsprom(carpeta, nombre_base)
_, espectro_400, _ = cargar_espectros_5shotsprom(carpeta, nombre_base)
_, espectro_300, _ = cargar_espectros_5shotsprom(carpeta, nombre_base)
_, espectro_200, _ = cargar_espectros_5shotsprom(carpeta, nombre_base)
_, espectro_100, _ = cargar_espectros_5shotsprom(carpeta, nombre_base)
_, espectro_50, _  = cargar_espectros_5shotsprom(carpeta, nombre_base)
_, espectro_35, _  = cargar_espectros_5shotsprom(carpeta, nombre_base)

# %% [markdown]
# ### Dark

# %%
carpeta = carpeta + '/dark'
dark_500, _, _ = cargar_espectros(carpeta, nombre_base)
dark_400, _, _ = cargar_espectros(carpeta, nombre_base)
dark_300, _, _ = cargar_espectros(carpeta, nombre_base)
dark_200, _, _ = cargar_espectros(carpeta, nombre_base)
dark_100, _, _ = cargar_espectros(carpeta, nombre_base)
dark_50, _, _ = cargar_espectros(carpeta, nombre_base)
dark_35, _, _ = cargar_espectros(carpeta, nombre_base)

# %% [markdown]
# ## Quitamos el Dark

# %%
#500
no_dark_500 = [[x - y for x, y in zip(row_a, row_b)]
     for row_a, row_b in zip(espectro_500, dark_500)]

#400
no_dark_400 = [[x - y for x, y in zip(row_a, row_b)]
     for row_a, row_b in zip(espectro_400, dark_400)]

#300
no_dark_300 = [[x - y for x, y in zip(row_a, row_b)]
     for row_a, row_b in zip(espectro_300, dark_300)]

#200
no_dark_200 = [[x - y for x, y in zip(row_a, row_b)]
     for row_a, row_b in zip(espectro_200, dark_200)]

#100
no_dark_100 = [[x - y for x, y in zip(row_a, row_b)]
     for row_a, row_b in zip(espectro_100, dark_100)]

#50
no_dark_50 = [[x - y for x, y in zip(row_a, row_b)]
     for row_a, row_b in zip(espectro_50, dark_50)]

#35
no_dark_35 = [[x - y for x, y in zip(row_a, row_b)]
     for row_a, row_b in zip(espectro_35, dark_35)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 a1,a2, a3 = [10,10],[5,5],[1,1]
# ----> 2 a= np.append(a1,a2,a3)
#       3 print(a)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\lib\function_base.py:5618, in append(arr, values, axis)
#    5616     values = ravel(values)
#    5617     axis = arr.ndim-1
# -> 5618 return concatenate((arr, values), axis=axis)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %% [markdown]
# ## Pre-Procesamos

# %%
norm_500, wvln = apply_preprocessing(no_dark_500,wavelength)
norm_400, _ = apply_preprocessing(no_dark_400,wavelength)
norm_300, _ = apply_preprocessing(no_dark_300,wavelength)
norm_200, _ = apply_preprocessing(no_dark_200,wavelength)
norm_100, _ = apply_preprocessing(no_dark_100,wavelength)
norm_50, _ = apply_preprocessing(no_dark_50,wavelength)
norm_35, _ = apply_preprocessing(no_dark_35,wavelength)

# %% [markdown]
# ### Visualizamos Datos Pre-Procesados

# %%
x = [wvln,wvln,wvln,wvln,wvln,wvln,wvln]
y = [norm_500,norm_400,norm_300,norm_200,norm_100,norm_50,norm_35]
nombres = ['500','400','300','200','100','50','35']
plot_spectra(x,y,'Espectro procesado según tiempo de integración', nombres=nombres)
